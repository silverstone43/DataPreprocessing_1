# %%
A = "안녕하세요 지금은 데이터 전처리 수업 시간입니다."
A[0:4]
# Out:
# '안녕하세'

# %%
A[-1]
# Out:
# '.'

# %%
A[-5:]
# Out:
# '간입니다.'

# %%
A[:-5]
# Out:
# '안녕하세요 지금은 데이터 전처리 수업 시'

# %%
A[21:23]
# Out:
# '시간'

# %%
A[-6:-4]
# Out:
# '시간'

# %%
print(("당신의 영어성적은 {}점입니다. 그리고 수학 성적은 {}점 입니다.").format(70,80))
# Out:
# 당신의 영어성적은 70점입니다. 그리고 수학 성적은 80점 입니다.

# %%
print(("{:.2f},{:.3f}").format(3.1415,3.1415))
# Out:
# 3.14,3.142

# %%
url = "https://www.youtube.com/"

# %%
str = url.replace("https://","")

# %%
str1 = url.replace("youtube","naver")

# %%
print(url)
print(str)
print(str1)
# Out:
# https://www.youtube.com/
# www.youtube.com/
# https://www.naver.com/

# %%
A = ["독고영재,50","김철수,30"]
type(A)
# Out:
# list

# %%
type(A[0])
# Out:
# str

# %%
A[0][0:4]
# Out:
# '독고영재'

# %%
a=["독고영재,50","김철수,30"]

# %%
b=["김철수,20","김영희,25"]

# %%
a.index(",")
# Out:
# 4

# %%
a[0][:a[0].index(",")]
# Out:
# '독고영재'

# %%
b[1][:b[1].index(",")]
# Out:
# '김영희'

# %%
a=["hi", 10, "80","김철수",50,50.6]

# %%
a.append(1)

# %%
a
# Out:
# ['hi', 10, '80', '김철수', 50.6]

# %%
a.pop(6)
# Out:
# 1

# %%
a
# Out:
# ['hi', 10, '김철수', 50, 50.6]

# %%
a.index(50)
# Out:
# 4

# %%
a.pop(4)
# Out:
# 50

# %%
b=a.index("80")

# %%
a.pop(b)
# Out:
# '80'

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
a=np.array([1,2,3,4,5])

# %%
a=np.delete(a,[1,3])

# %%
a
# Out:
# array([1, 3, 5])

# %%
a=a[a<=4]

# %%
a
# Out:
# array([1, 3])

# %%
a=[a!=4]

# %%
a
# Out:
# [True]

# %%
array1 = np.array([[1,2],[3,4]])
array2 = np.array([[5,6],[7,8]])

# %%
merged_array = np.vstack((array1,array2))

# %%
print(merged_array)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
merged_array = np.hstack((array1,array2))

# %%
print(merged_array)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
A={1:"김철수", 20:"박영희"}

# %%
A[1]
# Out:
# '김철수'

# %%
A[20]
# Out:
# '박영희'

# %%
A[2]
# Out:
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 A[2]
#
# KeyError: 2

# %%
A.get(1)
# Out:
# '김철수'

# %%
print(A.get(2))
# Out:
# None

# %%
A={"1-A":"김철수","20-B":"박영희"}

# %%
A["2-A"] = "영희"

# %%
A
# Out:
# {'1-A': '김철수', '20-B': '박영희', '2-A': '영희'}

# %%
del A["20-B"]
# Out:
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# Cell In[194], line 2
#       1 #1
# ----> 2 del A["20-B"]
#
# KeyError: '20-B'

# %%
A
# Out:
# {'1-A': '김철수', '2-A': '영희'}

# %%
a={
    "1-A":[1,2,3,4,5],
    "20-B":["A","B","C","D","E"]
}

# %%
a
# Out:
# {'1-A': [1, 2, 3, 4, 5], '20-B': ['A', 'B', 'C', 'D', 'E']}

# %%
a=np.array([1,2,3,4])
a = np.append(a,[4,5])

# %%
a
# Out:
# array([1, 2, 3, 4, 4, 5])

# %%
a=np.insert(a,2,[6,8])

# %%
a
# Out:
# array([1, 2, 6, 8, 3, 4, 4, 5])
