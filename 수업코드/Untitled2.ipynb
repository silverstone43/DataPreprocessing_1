# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'City':['New York','Paris','London']
    }
print(data)
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
data = np.array([
    [1,'Alice',30],
    [2,'Bob',25],
    [3,'Cjarlie',35]
])

# %%
df = pd.DataFrame(data)

# %%
df = pd.DataFrame(data, columns=['ID','Name','Age'])
print(df)
# Out:
#   ID     Name Age
# 0  1    Alice  30
# 1  2      Bob  25
# 2  3  Cjarlie  35

# %%
df=pd.read_csv('C:/Users/silst/OneDrive/바탕 화면/excelfile/국영수.csv',header=0,encoding='cp949')
df_c=pd.read_csv('C:/Users/silst/OneDrive/바탕 화면/excelfile/국영수.csv',header=None,encoding='cp949')

# %%
df
# Out:
#    국어  영어  수학 체육
# 0  50  88  21  상
# 1  41  87  54  중
# 2  85  65  84  상
# 3  61  85  13  중
# 4  54  41  21  하
# 5  84  47  87  하
# 6  77  98  65  상
# 7  87  58  54  중
# 8  54  22  78  히

# %%
df_c
# Out:
#     0   1   2   3
# 0  국어  영어  수학  체육
# 1  50  88  21   상
# 2  41  87  54   중
# 3  85  65  84   상
# 4  61  85  13   중
# 5  54  41  21   하
# 6  84  47  87   하
# 7  77  98  65   상
# 8  87  58  54   중
# 9  54  22  78   히

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['국어', '영어', '수학', '체육'], dtype='object')

# %%
df.dtypes
# Out:
# 국어     int64
# 영어     int64
# 수학     int64
# 체육    object
# dtype: object

# %%
df.describe()
# Out:
#               국어         영어         수학
# count   9.000000   9.000000   9.000000
# mean   65.888889  65.666667  53.000000
# std    17.467430  25.729361  28.583212
# min    41.000000  22.000000  13.000000
# 25%    54.000000  47.000000  21.000000
# 50%    61.000000  65.000000  54.000000
# 75%    84.000000  87.000000  78.000000
# max    87.000000  98.000000  87.000000

# %%
df.head()
# Out:
#    국어  영어  수학 체육
# 0  50  88  21  상
# 1  41  87  54  중
# 2  85  65  84  상
# 3  61  85  13  중
# 4  54  41  21  하

# %%
df.tail()
# Out:
#    국어  영어  수학 체육
# 4  54  41  21  하
# 5  84  47  87  하
# 6  77  98  65  상
# 7  87  58  54  중
# 8  54  22  78  히

# %%
df.isnull().sum()
# Out:
# 국어    0
# 영어    0
# 수학    0
# 체육    0
# dtype: int64

# %%
df['체육'].value_counts()
# Out:
# 체육
# 상    3
# 중    3
# 하    2
# 히    1
# Name: count, dtype: int64

# %%
df['체육'].unique()
# Out:
# array(['상', '중', '하', '히'], dtype=object)

# %%
df['체육'].nunique()
# Out:
# 4

# %%
#error
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\CGData\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 #error
# ----> 2 df[0]
#
# ...

# %%
df['국어']
# Out:
# 0    50
# 1    41
# 2    85
# 3    61
# 4    54
# 5    84
# 6    77
# 7    87
# 8    54
# Name: 국어, dtype: int64

# %%
df["합계"] = df["국어"] + df["영어"]
df
# Out:
#    국어  영어  수학 체육   합계
# 0  50  88  21  상  138
# 1  41  87  54  중  128
# 2  85  65  84  상  150
# 3  61  85  13  중  146
# 4  54  41  21  하   95
# 5  84  47  87  하  131
# 6  77  98  65  상  175
# 7  87  58  54  중  145
# 8  54  22  78  히   76

# %%
columns = ["국어","영어","수학"]
selected_columns = df[columns]
selected_columns
# Out:
#    국어  영어  수학
# 0  50  88  21
# 1  41  87  54
# 2  85  65  84
# 3  61  85  13
# 4  54  41  21
# 5  84  47  87
# 6  77  98  65
# 7  87  58  54
# 8  54  22  78

# %%
df.loc[:,"영어"]
# Out:
# 0    88
# 1    87
# 2    65
# 3    85
# 4    41
# 5    47
# 6    98
# 7    58
# 8    22
# Name: 영어, dtype: int64

# %%
columns = ["국어","영어","수학"]
selected_columns = df.loc[:,columns]
selected_columns
# Out:
#    국어  영어  수학
# 0  50  88  21
# 1  41  87  54
# 2  85  65  84
# 3  61  85  13
# 4  54  41  21
# 5  84  47  87
# 6  77  98  65
# 7  87  58  54
# 8  54  22  78

# %%
df
# Out:
#    국어  영어  수학 체육   합계
# 0  50  88  21  상  138
# 1  41  87  54  중  128
# 2  85  65  84  상  150
# 3  61  85  13  중  146
# 4  54  41  21  하   95
# 5  84  47  87  하  131
# 6  77  98  65  상  175
# 7  87  58  54  중  145
# 8  54  22  78  히   76

# %%
df.drop(["체육"],axis=1)
# Out:
#    국어  영어  수학   합계
# 0  50  88  21  138
# 1  41  87  54  128
# 2  85  65  84  150
# 3  61  85  13  146
# 4  54  41  21   95
# 5  84  47  87  131
# 6  77  98  65  175
# 7  87  58  54  145
# 8  54  22  78   76

# %%
data = {
    'A':[1,2,3,4],
    'B':[4.1,3.5,2.1,5.7],
    'C':['one','two','three','four']
}
df = pd.DataFrame(data)
df
# Out:
#    A    B      C
# 0  1  4.1    one
# 1  2  3.5    two
# 2  3  2.1  three
# 3  4  5.7   four

# %%
df['A']=df['A'].astype(float)
df['B']=df['B'].astype(int)
df['C']=df['C'].astype('category')

# %%
df['C'].dtype
# Out:
# CategoricalDtype(categories=['four', 'one', 'three', 'two'], ordered=False, categories_dtype=object)

# %%
df
# Out:
#      A  B      C
# 0  1.0  4    one
# 1  2.0  3    two
# 2  3.0  2  three
# 3  4.0  5   four

# %%
df['A']=df['A'].astype('str')
df
# Out:
#      A  B      C
# 0  1.0  4    one
# 1  2.0  3    two
# 2  3.0  2  three
# 3  4.0  5   four

# %%
df['A'].dtype
# Out:
# dtype('O')

# %%
#문자를 num으로 변경할 떄 파이썬이 못알아먹음.
df['A']=df['A'].astype(int)
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df['A']=df['A'].astype(int)
#
# File ~\anaconda3\envs\CGData\lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\envs\CGData\lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
# ...

# %%
df = df.rename(columns={
    'A':'국어',
    'B':'영어',
    'C':'번호'
})
df
# Out:
#     국어  영어     번호
# 0  1.0   4    one
# 1  2.0   3    two
# 2  3.0   2  three
# 3  4.0   5   four

# %%
data = {
    'Numeric1':[1,np.nan,3,4],
    'Numeric2':[5,6,np.nan,8.2],
    'Categoty':['dog',np.nan,'cat','dog']
}

# %%
df = pd.DataFrame(data)

# %%
A=df.select_dtypes(include=["number"]).columns
A
# Out:
# Index(['Numeric1', 'Numeric2'], dtype='object')

# %%
df[A]
# Out:
#    Numeric1  Numeric2
# 0       1.0       5.0
# 1       NaN       6.0
# 2       3.0       NaN
# 3       4.0       8.2

# %%
B=df.select_dtypes(include=['object','category']).columns
B
# Out:
# Index(['Categoty'], dtype='object')

# %%
df[B]
# Out:
#   Categoty
# 0      dog
# 1      NaN
# 2      cat
# 3      dog

# %%
df[A].fillna(df[A].median())
# Out:
#    Numeric1  Numeric2
# 0       1.0       5.0
# 1       3.0       6.0
# 2       3.0       6.0
# 3       4.0       8.2

# %%
df[A].fillna(df[A].mean())
# Out:
#    Numeric1  Numeric2
# 0  1.000000       5.0
# 1  2.666667       6.0
# 2  3.000000       6.4
# 3  4.000000       8.2

# %%
df
# Out:
#    Numeric1  Numeric2 Categoty
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 2       3.0       NaN      cat
# 3       4.0       8.2      dog

# %%
df1 = pd.DataFrame({
    'a':['a0','a1','a2','a3'],
    'b':['b0','b1','b2','b3'],
    'c':['c0','c1','c2','c3']
})
df2 = pd.DataFrame({
    'a':['a2','a3','a4','a5'],
    'b':['b2','b3','b4','b5'],
    'c':['c2','c3','c4','c5'],
    'd':['d2','d3','c4','c5']
})

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 0  a2  b2  c2   d2
# 1  a3  b3  c3   d3
# 2  a4  b4  c4   c4
# 3  a5  b5  c5   c5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     a   b   c   a   b   c   d
# 0  a0  b0  c0  a2  b2  c2  d2
# 1  a1  b1  c1  a3  b3  c3  d3
# 2  a2  b2  c2  a4  b4  c4  c4
# 3  a3  b3  c3  a5  b5  c5  c5

# %%
pd.concat([df[A],df[B]],axis=1)
# Out:
#    Numeric1  Numeric2 Categoty
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 2       3.0       NaN      cat
# 3       4.0       8.2      dog

# %%
df[(df['Numeric2']>=6) & (df['Numeric2'] <= 10)]
# Out:
#    Numeric1  Numeric2 Categoty
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog

# %%
df[(df['Numeric2']>=6) | (df['Numeric2'] <= 10)]
# Out:
#    Numeric1  Numeric2 Categoty
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog

# %%
import numpy as np
array1 = np.array([[1,2],[3,4]])
array2 = np.array([[5,6],[7,8]])
print(np.vstack(array1, array2))
print(np.hstack(array1, array2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 4
#       2 array1 = np.array([[1,2],[3,4]])
#       3 array2 = np.array([[5,6],[7,8]])
# ----> 4 print(np.vstack(array1, array2))
#       5 print(np.hstack(array1, array2))
#
# TypeError: vstack() takes 1 positional argument but 2 were given

# %%
import numpy as np
dict = {"Numeric1" : [1,np.nan,3,4], 
       'Numeric2' : [5,6,np.nan,9.2]}

dict.fillna(dict.median())
# DataFrame형태로 바꾼 후 채워 줄 수 있
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       1 import numpy as np
#       2 dict = {"Numeric1" : [1,np.nan,3,4],
#       3        'Numeric2' : [5,6,np.nan,9.2]}
# ----> 5 dict.fillna(dict.median())
#
# AttributeError: 'dict' object has no attribute 'fillna'
