# %%
lst1 = [10,20,30,[1,2,3]]

# %%
lst1[3]
# Out:
# [1, 2, 3]

# %%
math_s = [20,30,40,50,60]
eng_s = [50,70,50,60,90]

# %%
url = "https://www.youtube.com/"

# %%
str1 = url.replace("https://","")

# %%
str2 = str1.replace("youtube","naver")

# %%
str2
# Out:
# 'www.naver.com/'

# %%
sum(math_s)/5
# Out:
# 40.0

# %%
sum(eng_s)/5
# Out:
# 64.0

# %%
import numpy as np

# %%
arr1 = np.array([1,2,100,4,5,900])

# %%
arr1=np.delete(arr1,[2,5])

# %%
arr1
# Out:
# array([1, 2, 4, 5])

# %%
dict1 = {
        "math" : [20,30,40,50,60],
        "eng" : [50,70,50,60,90]
}

# %%
dict1
# Out:
# {'math': [20, 30, 40, 50, 60], 'eng': [50, 70, 50, 60, 90]}

# %%
math_1 = dict1["math"][0]
eng_3 = dict1["eng"][2]

# %%
math_1 + eng_3
# Out:
# 70
